# %% [markdown]
# #Semantic Segmentation using SegNet (VGG16 & ResNet50)
# ## Submitted By: Muhammad Jawad Bashir
# ##Registration No: 330295

# %% [markdown]
# ###1. Loading Data

# %%
# For loading gdrive on colab
from google.colab import drive
import os

if os.path.exists('/content/gdrive')==False:
    drive.mount('/content/gdrive')
    print('Google Drive is mounted\n')
else:
    print('Google Drive is already mounted\n')
# Out:
# Mounted at /content/gdrive
# Google Drive is mounted

# %% [markdown]
# ###2. Library Installation

# %%
# !pip install imgaug==0.2.9
#!pip install keras-segmentation
#!pip install --target='/content/gdrive/MyDrive/Colab Notebooks' keras-segmentation

# %%
import glob
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow import keras
import imgaug as ia
from imgaug import augmenters as iaa

# %% [markdown]
# ###3. Custom Metrics
# Dice Coeffecient is not implemented in library. Library module 'train.py' has been modified to include it. Ony IU Score and Crossentropy is implemented in library.

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %% [markdown]
# ###4. DataLoader
# Dataset's train folder is splitted into train-validation (0.8 & 0.2) using split-folder library and splitted dataset is uploaded on GDrive for ease of work with this library.We can also use the following function.

# %%
# def Data_Loader(images_path, masks_path):
#         train_images = []

#         for directory_path in glob.glob(images_path):
#             for img_path in glob.glob(os.path.join(directory_path, "*.png")):
#                 #print(img_path)
#                 img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
#                 #img = cv2.resize(img, (SIZE_Y, SIZE_X))
#                 #img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
#                 train_images.append(img)
#                 #train_labels.append(label)
#         #Convert list to array for machine learning processing        
#         train_images = np.array(train_images)

#         #Capture mask/label info as a list
#         train_masks = [] 
#         for directory_path in glob.glob(masks_paths):
#             for mask_path in glob.glob(os.path.join(directory_path, "*.png")):
#                 mask = cv2.imread(mask_path, 0)       
#                 #mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
#                 #mask = cv2.cvtColor(mask, cv2.COLOR_RGB2BGR)
#                 train_masks.append(mask)
#                 #train_labels.append(label)
#         #Convert list to array for machine learning processing          
#         train_masks = np.array(train_masks)

#         #Use customary x_train and y_train variables
#         X = train_images
#         Y = train_masks
#         Y = np.expand_dims(Y, axis=3) #May not be necessary.. leftover from previous code
#         return X, Y

# %%
# train_images = "/content/gdrive/MyDrive/dataset1/images_prepped_train"
# tain_masks = "/content/gdrive/MyDrive/dataset1/annotations_prepped_train"
# X, Y = Data_Loader(train_images, train_masks)
# from sklearn.model_selection import train_test_split
#         x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
original_image = "/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_train/0001TP_006690.png"
label_image_semantic = "/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_train/0001TP_006690.png"

fig, axs = plt.subplots(1, 2, figsize=(10, 8), constrained_layout=True)

axs[0].imshow( Image.open(original_image))
axs[0].grid(False)

label_image_semantic = Image.open(label_image_semantic)
label_image_semantic = np.asarray(label_image_semantic)
axs[1].imshow(label_image_semantic)
axs[1].grid(False)

# %% [markdown]
# ###5. Library Path
# Library is installed in my drive for modification and ease of access instead of installing it on every run.

# %%
import sys
nb_path = '/content/gdrive/MyDrive/Colab Notebooks'
#os.symlink('/content/gdrive/MyDrive/Colab Notebooks', nb_path)
sys.path.insert(0,nb_path)

# %%
import keras_segmentation

# %% [markdown]
# ###6. SegNet with VGG-16 Backbone

# %%
from keras_segmentation.models.segnet import vgg_segnet

model_vgg = vgg_segnet(n_classes = 11, input_height=320, input_width=640 )

# %%
# !pip install split-folders
# import split-folders
# splitfolders.ratio("input_folder", output="output", seed=1337, ratio=(.8, .2), group_prefix=None)

# %% [markdown]
# ###7. Custom Data Augmentation
# Augmentation function is also manually modified in library and then used.

# %%
def aug_ment():
    return iaa.OneOf([
        iaa.Sequential([iaa.Fliplr(0.5), iaa.Flipud(0.2)]),
        iaa.CropAndPad(percent=(-0.05, 0.1),
                       pad_mode='constant',
                       pad_cval=(0, 255)),
        iaa.Crop(percent=(0.0, 0.1)),
        iaa.Crop(percent=(0.3, 0.5)),
        iaa.Crop(percent=(0.3, 0.5)),
        iaa.Crop(percent=(0.3, 0.5)),
        iaa.Sequential([
            iaa.Affine(
                    # scale images to 80-120% of their size,
                    # individually per axis
                    scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
                    # translate by -20 to +20 percent (per axis)
                    translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
                    rotate=(-45, 45),  # rotate by -45 to +45 degrees
                    shear=(-16, 16),  # shear by -16 to +16 degrees
                    # use nearest neighbour or bilinear interpolation (fast)
                    order=[0, 1],
                    # if mode is constant, use a cval between 0 and 255
                    mode='constant',
                    cval=(0, 255),
                    # use any of scikit-image's warping modes
                    # (see 2nd image from the top for examples)
            ),
                   iaa.Sometimes(0.2, iaa.GaussianBlur(sigma=(0, 3.0))),
                   iaa.Sometimes(0.2, iaa.MotionBlur(k=15, angle=[-45, 45])),
                   iaa.Sometimes(0.2, iaa.MultiplyHue((0.5, 1.5))),
                   iaa.Sometimes(0.2, iaa.MultiplySaturation((0.5, 1.5))),
                   iaa.Sometimes(0.34, iaa.MultiplyHueAndSaturation((0.5, 1.5),
                                                         per_channel=True)),])
    ])

# %%
#model.add_metric()
#model.train()
batch_size = 8

history_vgg = model_vgg.train(
    train_images =  "/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_train/",
    train_annotations = "/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_train/",
    validate=True,
    val_images="/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_valid",
    val_annotations="/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_valid",
    checkpoints_path = "/tmp/vgg_segnet_111" , 
    epochs=30,
    do_augment=True, # enable augmentation, 
    augmentation_name = 'aug_all',
    verify_dataset=False,
    batch_size = batch_size,
    val_batch_size = batch_size,
    steps_per_epoch = np.ceil(294 / batch_size),
    val_steps_per_epoch = np.ceil(73 / batch_size),
    )
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/keras_segmentation/train.py:170: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   use_multiprocessing=gen_use_multiprocessing)
# /usr/local/lib/python3.7/dist-packages/imgaug/augmenters/segmentation.py:191: FutureWarning: skimage.measure.label's indexing starts from 0. In future version it will start from 1. To disable this warning, explicitely set the `start_label` parameter to 1.
#   segments = segmentation.slic(image, n_segments=n_segments_samples[i], compactness=10)
# Epoch 1/30
# 37/37 [==============================] - ETA: 0s - loss: 2.7549 - accuracy: 0.1470 - dice_coef: 0.1112saved  /tmp/vgg_segnet_111.0
# 37/37 [==============================] - 205s 5s/step - loss: 2.7549 - accuracy: 0.1470 - dice_coef: 0.1112 - val_loss: 3.7094 - val_accuracy: 0.1890 - val_dice_coef: 0.1805
# Epoch 2/30
# 37/37 [==============================] - ETA: 0s - loss: 2.1531 - accuracy: 0.3537 - dice_coef: 0.2012saved  /tmp/vgg_segnet_111.1
# 37/37 [==============================] - 128s 4s/step - loss: 2.1531 - accuracy: 0.3537 - dice_coef: 0.2012 - val_loss: 2.0021 - val_accuracy: 0.4084 - val_dice_coef: 0.3340
# Epoch 3/30
# 37/37 [==============================] - ETA: 0s - loss: 1.7407 - accuracy: 0.4896 - dice_coef: 0.3026saved  /tmp/vgg_segnet_111.2
# 37/37 [==============================] - 129s 3s/step - loss: 1.7407 - accuracy: 0.4896 - dice_coef: 0.3026 - val_loss: 1.4064 - val_accuracy: 0.5788 - val_dice_coef: 0.4608
# Epoch 4/30
# 37/37 [==============================] - ETA: 0s - loss: 1.5211 - accuracy: 0.5608 - dice_coef: 0.3760saved  /tmp/vgg_segnet_111.3
# 37/37 [==============================] - 131s 4s/step - loss: 1.5211 - accuracy: 0.5608 - dice_coef: 0.3760 - val_loss: 1.1176 - val_accuracy: 0.6605 - val_dice_coef: 0.5428
# Epoch 5/30
# 37/37 [==============================] - ETA: 0s - loss: 1.3215 - accuracy: 0.6166 - dice_coef: 0.4410saved  /tmp/vgg_segnet_111.4
# 37/37 [==============================] - 123s 3s/step - loss: 1.3215 - accuracy: 0.6166 - dice_coef: 0.4410 - val_loss: 0.9731 - val_accuracy: 0.7006 - val_dice_coef: 0.5954
# Epoch 6/30
# 37/37 [==============================] - ETA: 0s - loss: 1.3063 - accuracy: 0.6158 - dice_coef: 0.4562saved  /tmp/vgg_segnet_111.5
# 37/37 [==============================] - 126s 3s/step - loss: 1.3063 - accuracy: 0.6158 - dice_coef: 0.4562 - val_loss: 0.8972 - val_accuracy: 0.7154 - val_dice_coef: 0.6148
# Epoch 7/30
# 37/37 [==============================] - ETA: 0s - loss: 1.2129 - accuracy: 0.6433 - dice_coef: 0.4874saved  /tmp/vgg_segnet_111.6
# 37/37 [==============================] - 121s 3s/step - loss: 1.2129 - accuracy: 0.6433 - dice_coef: 0.4874 - val_loss: 0.8270 - val_accuracy: 0.7251 - val_dice_coef: 0.6294
# Epoch 8/30
# 37/37 [==============================] - ETA: 0s - loss: 1.1533 - accuracy: 0.6621 - dice_coef: 0.5051saved  /tmp/vgg_segnet_111.7
# 37/37 [==============================] - 125s 3s/step - loss: 1.1533 - accuracy: 0.6621 - dice_coef: 0.5051 - val_loss: 0.7838 - val_accuracy: 0.7354 - val_dice_coef: 0.6478
# Epoch 9/30
# 37/37 [==============================] - ETA: 0s - loss: 1.0882 - accuracy: 0.6756 - dice_coef: 0.5285saved  /tmp/vgg_segnet_111.8
# 37/37 [==============================] - 128s 4s/step - loss: 1.0882 - accuracy: 0.6756 - dice_coef: 0.5285 - val_loss: 0.7483 - val_accuracy: 0.7423 - val_dice_coef: 0.6536
# Epoch 10/30
# 37/37 [==============================] - ETA: 0s - loss: 1.0543 - accuracy: 0.6862 - dice_coef: 0.5440saved  /tmp/vgg_segnet_111.9
# 37/37 [==============================] - 124s 3s/step - loss: 1.0543 - accuracy: 0.6862 - dice_coef: 0.5440 - val_loss: 0.7164 - val_accuracy: 0.7499 - val_dice_coef: 0.6624
# Epoch 11/30
# 37/37 [==============================] - ETA: 0s - loss: 1.0661 - accuracy: 0.6860 - dice_coef: 0.5457saved  /tmp/vgg_segnet_111.10
# 37/37 [==============================] - 128s 4s/step - loss: 1.0661 - accuracy: 0.6860 - dice_coef: 0.5457 - val_loss: 0.7055 - val_accuracy: 0.7515 - val_dice_coef: 0.6604
# Epoch 12/30
# 37/37 [==============================] - ETA: 0s - loss: 1.0312 - accuracy: 0.6923 - dice_coef: 0.5535saved  /tmp/vgg_segnet_111.11
# 37/37 [==============================] - 121s 3s/step - loss: 1.0312 - accuracy: 0.6923 - dice_coef: 0.5535 - val_loss: 0.6766 - val_accuracy: 0.7553 - val_dice_coef: 0.6677
# Epoch 13/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9339 - accuracy: 0.7144 - dice_coef: 0.5765saved  /tmp/vgg_segnet_111.12
# 37/37 [==============================] - 111s 3s/step - loss: 0.9339 - accuracy: 0.7144 - dice_coef: 0.5765 - val_loss: 0.6622 - val_accuracy: 0.7602 - val_dice_coef: 0.6726
# Epoch 14/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9271 - accuracy: 0.7165 - dice_coef: 0.5801saved  /tmp/vgg_segnet_111.13
# 37/37 [==============================] - 118s 3s/step - loss: 0.9271 - accuracy: 0.7165 - dice_coef: 0.5801 - val_loss: 0.6422 - val_accuracy: 0.7610 - val_dice_coef: 0.6741
# Epoch 15/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9728 - accuracy: 0.7058 - dice_coef: 0.5734saved  /tmp/vgg_segnet_111.14
# 37/37 [==============================] - 123s 3s/step - loss: 0.9728 - accuracy: 0.7058 - dice_coef: 0.5734 - val_loss: 0.6347 - val_accuracy: 0.7635 - val_dice_coef: 0.6786
# Epoch 16/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9105 - accuracy: 0.7215 - dice_coef: 0.5893saved  /tmp/vgg_segnet_111.15
# 37/37 [==============================] - 124s 3s/step - loss: 0.9105 - accuracy: 0.7215 - dice_coef: 0.5893 - val_loss: 0.6323 - val_accuracy: 0.7674 - val_dice_coef: 0.6831
# Epoch 17/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9387 - accuracy: 0.7151 - dice_coef: 0.5827saved  /tmp/vgg_segnet_111.16
# 37/37 [==============================] - 130s 4s/step - loss: 0.9387 - accuracy: 0.7151 - dice_coef: 0.5827 - val_loss: 0.6085 - val_accuracy: 0.7680 - val_dice_coef: 0.6855
# Epoch 18/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9284 - accuracy: 0.7167 - dice_coef: 0.5872saved  /tmp/vgg_segnet_111.17
# 37/37 [==============================] - 128s 3s/step - loss: 0.9284 - accuracy: 0.7167 - dice_coef: 0.5872 - val_loss: 0.6113 - val_accuracy: 0.7701 - val_dice_coef: 0.6844
# Epoch 19/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8978 - accuracy: 0.7247 - dice_coef: 0.5949saved  /tmp/vgg_segnet_111.18
# 37/37 [==============================] - 125s 3s/step - loss: 0.8978 - accuracy: 0.7247 - dice_coef: 0.5949 - val_loss: 0.5975 - val_accuracy: 0.7735 - val_dice_coef: 0.6885
# Epoch 20/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8892 - accuracy: 0.7262 - dice_coef: 0.5961saved  /tmp/vgg_segnet_111.19
# 37/37 [==============================] - 125s 3s/step - loss: 0.8892 - accuracy: 0.7262 - dice_coef: 0.5961 - val_loss: 0.5827 - val_accuracy: 0.7760 - val_dice_coef: 0.6958
# Epoch 21/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8480 - accuracy: 0.7363 - dice_coef: 0.6085saved  /tmp/vgg_segnet_111.20
# 37/37 [==============================] - 125s 3s/step - loss: 0.8480 - accuracy: 0.7363 - dice_coef: 0.6085 - val_loss: 0.5839 - val_accuracy: 0.7766 - val_dice_coef: 0.6955
# Epoch 22/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8336 - accuracy: 0.7427 - dice_coef: 0.6149saved  /tmp/vgg_segnet_111.21
# 37/37 [==============================] - 123s 3s/step - loss: 0.8336 - accuracy: 0.7427 - dice_coef: 0.6149 - val_loss: 0.5729 - val_accuracy: 0.7780 - val_dice_coef: 0.6955
# Epoch 23/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8508 - accuracy: 0.7354 - dice_coef: 0.6092saved  /tmp/vgg_segnet_111.22
# 37/37 [==============================] - 133s 4s/step - loss: 0.8508 - accuracy: 0.7354 - dice_coef: 0.6092 - val_loss: 0.5701 - val_accuracy: 0.7824 - val_dice_coef: 0.6986
# Epoch 24/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8581 - accuracy: 0.7338 - dice_coef: 0.6062saved  /tmp/vgg_segnet_111.23
# 37/37 [==============================] - 120s 3s/step - loss: 0.8581 - accuracy: 0.7338 - dice_coef: 0.6062 - val_loss: 0.5616 - val_accuracy: 0.7799 - val_dice_coef: 0.6988
# Epoch 25/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8176 - accuracy: 0.7455 - dice_coef: 0.6185saved  /tmp/vgg_segnet_111.24
# 37/37 [==============================] - 127s 3s/step - loss: 0.8176 - accuracy: 0.7455 - dice_coef: 0.6185 - val_loss: 0.5516 - val_accuracy: 0.7873 - val_dice_coef: 0.7072
# Epoch 26/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8157 - accuracy: 0.7443 - dice_coef: 0.6191saved  /tmp/vgg_segnet_111.25
# 37/37 [==============================] - 124s 3s/step - loss: 0.8157 - accuracy: 0.7443 - dice_coef: 0.6191 - val_loss: 0.5505 - val_accuracy: 0.7859 - val_dice_coef: 0.7060
# Epoch 27/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8318 - accuracy: 0.7379 - dice_coef: 0.6156saved  /tmp/vgg_segnet_111.26
# 37/37 [==============================] - 132s 4s/step - loss: 0.8318 - accuracy: 0.7379 - dice_coef: 0.6156 - val_loss: 0.5422 - val_accuracy: 0.7874 - val_dice_coef: 0.7071
# Epoch 28/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8235 - accuracy: 0.7409 - dice_coef: 0.6186saved  /tmp/vgg_segnet_111.27
# 37/37 [==============================] - 126s 3s/step - loss: 0.8235 - accuracy: 0.7409 - dice_coef: 0.6186 - val_loss: 0.5446 - val_accuracy: 0.7878 - val_dice_coef: 0.7087
# Epoch 29/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8150 - accuracy: 0.7446 - dice_coef: 0.6216saved  /tmp/vgg_segnet_111.28
# 37/37 [==============================] - 125s 3s/step - loss: 0.8150 - accuracy: 0.7446 - dice_coef: 0.6216 - val_loss: 0.5384 - val_accuracy: 0.7878 - val_dice_coef: 0.7119
# Epoch 30/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7882 - accuracy: 0.7524 - dice_coef: 0.6285saved  /tmp/vgg_segnet_111.29
# 37/37 [==============================] - 138s 4s/step - loss: 0.7882 - accuracy: 0.7524 - dice_coef: 0.6285 - val_loss: 0.5350 - val_accuracy: 0.7918 - val_dice_coef: 0.7156

# %% [markdown]
# ###8. Results for SegNet (VGG-16)

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(model_vgg.history.history["loss"], label="loss")
plt.plot(model_vgg.history.history["val_loss"], label="val_loss")
plt.plot( np.argmin(model_vgg.history.history["val_loss"]), np.min(model_vgg.history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();
plt.show()
#plt.savefig('/tmp/'+str(config['Model'])+'/train_loss.png')

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(model_vgg.history.history["dice_coef"], label="dice_coef")
plt.plot(model_vgg.history.history["val_dice_coef"], label="val_dice_coef")
plt.plot( np.argmax(model_vgg.history.history["val_dice_coef"]), np.max(model_vgg.history.history["val_dice_coef"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Dice Coeff")
plt.legend();
plt.show()
#plt.savefig('./Results/plots/'+str(config['Model'])+'/train_dice.png')

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(model_vgg.history.history["accuracy"], label="accuracy")
plt.plot(model_vgg.history.history["val_accuracy"], label="val_accuracy")
plt.plot( np.argmax(model_vgg.history.history["val_accuracy"]), np.max(model_vgg.history.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend();
plt.show()
# plt.savefig('./Results/plots/'+str(config['Model'])+'/train_accuracy.png

# %%
print(model_vgg.evaluate_segmentation( 
    inp_images_dir="/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_test"  , 
    annotations_dir="/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_test",
    ) 
)
# Out:
# 101it [00:52,  1.93it/s]
# {'frequency_weighted_IU': 0.39333882789083585, 'mean_IU': 0.03656461466636201, 'class_wise_IU': array([4.00092075e-01, 1.07921100e-05, 0.00000000e+00, 1.18310719e-04,
#        1.27893593e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.37198577e-03, 4.37144820e-04, 5.25596552e-05])}

# %%
his_vgg = model_vgg.history

# %%
pred_img = model_vgg.predict_segmentation(
    inp="/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_test/0016E5_07965.png",
    out_fname="/tmp/pred_img.png", overlay_img=True, show_legends=True,
    class_names = [ "Sky", "Building", "Pole","Road","Pavement","Tree","SignSymbol", "Fence", "Car","Pedestrian", "Bicyclist"]
)

from IPython.display import Image
Image('/tmp/pred_img.png')

# %% [markdown]
# ###9. SegNet with ResNet50 Backbone

# %%
from keras_segmentation.models.segnet import resnet50_segnet
model_res = resnet50_segnet(n_classes = 11, input_height=320, input_width=640 )

# %%
#model2.summary()

# %%
batch_size= 8
history_res = model_res.train(
    train_images =  "/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_train/",
    train_annotations = "/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_train/",
    validate=True,
    val_images="/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_valid",
    val_annotations="/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_valid",
    checkpoints_path = "/tmp/res_segnet_2001" , 
    epochs=30,
    do_augment=True, # enable augmentation 
    augmentation_name = 'aug_all',
    verify_dataset=False,
    batch_size = batch_size,
    val_batch_size = batch_size,
    steps_per_epoch = np.ceil(294 / batch_size),
    val_steps_per_epoch = np.ceil(73 / batch_size),
    )
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/keras_segmentation/train.py:170: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   use_multiprocessing=gen_use_multiprocessing)
# /usr/local/lib/python3.7/dist-packages/imgaug/augmenters/segmentation.py:191: FutureWarning: skimage.measure.label's indexing starts from 0. In future version it will start from 1. To disable this warning, explicitely set the `start_label` parameter to 1.
#   segments = segmentation.slic(image, n_segments=n_segments_samples[i], compactness=10)
# Epoch 1/30
# 37/37 [==============================] - ETA: 0s - loss: 2.6102 - accuracy: 0.1438 - dice_coef: 0.1184saved  /tmp/res_segnet_2001.0
# 37/37 [==============================] - 129s 3s/step - loss: 2.6102 - accuracy: 0.1438 - dice_coef: 0.1184 - val_loss: 2.5849 - val_accuracy: 0.1388 - val_dice_coef: 0.1294
# Epoch 2/30
# 37/37 [==============================] - ETA: 0s - loss: 2.1202 - accuracy: 0.2871 - dice_coef: 0.1877saved  /tmp/res_segnet_2001.1
# 37/37 [==============================] - 125s 3s/step - loss: 2.1202 - accuracy: 0.2871 - dice_coef: 0.1877 - val_loss: 1.8723 - val_accuracy: 0.3198 - val_dice_coef: 0.2288
# Epoch 3/30
# 37/37 [==============================] - ETA: 0s - loss: 1.7981 - accuracy: 0.4139 - dice_coef: 0.2584saved  /tmp/res_segnet_2001.2
# 37/37 [==============================] - 124s 3s/step - loss: 1.7981 - accuracy: 0.4139 - dice_coef: 0.2584 - val_loss: 1.4596 - val_accuracy: 0.4816 - val_dice_coef: 0.3284
# Epoch 4/30
# 37/37 [==============================] - ETA: 0s - loss: 1.5875 - accuracy: 0.4944 - dice_coef: 0.3152saved  /tmp/res_segnet_2001.3
# 37/37 [==============================] - 119s 3s/step - loss: 1.5875 - accuracy: 0.4944 - dice_coef: 0.3152 - val_loss: 1.1964 - val_accuracy: 0.5806 - val_dice_coef: 0.4097
# Epoch 5/30
# 37/37 [==============================] - ETA: 0s - loss: 1.4327 - accuracy: 0.5533 - dice_coef: 0.3663saved  /tmp/res_segnet_2001.4
# 37/37 [==============================] - 126s 3s/step - loss: 1.4327 - accuracy: 0.5533 - dice_coef: 0.3663 - val_loss: 1.0311 - val_accuracy: 0.6449 - val_dice_coef: 0.4742
# Epoch 6/30
# 37/37 [==============================] - ETA: 0s - loss: 1.2994 - accuracy: 0.6014 - dice_coef: 0.4100saved  /tmp/res_segnet_2001.5
# 37/37 [==============================] - 118s 3s/step - loss: 1.2994 - accuracy: 0.6014 - dice_coef: 0.4100 - val_loss: 0.9264 - val_accuracy: 0.6812 - val_dice_coef: 0.5204
# Epoch 7/30
# 37/37 [==============================] - ETA: 0s - loss: 1.2055 - accuracy: 0.6322 - dice_coef: 0.4433saved  /tmp/res_segnet_2001.6
# 37/37 [==============================] - 123s 3s/step - loss: 1.2055 - accuracy: 0.6322 - dice_coef: 0.4433 - val_loss: 0.8452 - val_accuracy: 0.7031 - val_dice_coef: 0.5558
# Epoch 8/30
# 37/37 [==============================] - ETA: 0s - loss: 1.1168 - accuracy: 0.6616 - dice_coef: 0.4752saved  /tmp/res_segnet_2001.7
# 37/37 [==============================] - 120s 3s/step - loss: 1.1168 - accuracy: 0.6616 - dice_coef: 0.4752 - val_loss: 0.7937 - val_accuracy: 0.7218 - val_dice_coef: 0.5844
# Epoch 9/30
# 37/37 [==============================] - ETA: 0s - loss: 1.0981 - accuracy: 0.6655 - dice_coef: 0.4890saved  /tmp/res_segnet_2001.8
# 37/37 [==============================] - 125s 3s/step - loss: 1.0981 - accuracy: 0.6655 - dice_coef: 0.4890 - val_loss: 0.7384 - val_accuracy: 0.7315 - val_dice_coef: 0.6053
# Epoch 10/30
# 37/37 [==============================] - ETA: 0s - loss: 1.0527 - accuracy: 0.6782 - dice_coef: 0.5063saved  /tmp/res_segnet_2001.9
# 37/37 [==============================] - 129s 4s/step - loss: 1.0527 - accuracy: 0.6782 - dice_coef: 0.5063 - val_loss: 0.7030 - val_accuracy: 0.7429 - val_dice_coef: 0.6230
# Epoch 11/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9805 - accuracy: 0.7063 - dice_coef: 0.5354saved  /tmp/res_segnet_2001.10
# 37/37 [==============================] - 121s 3s/step - loss: 0.9805 - accuracy: 0.7063 - dice_coef: 0.5354 - val_loss: 0.6792 - val_accuracy: 0.7517 - val_dice_coef: 0.6376
# Epoch 12/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9838 - accuracy: 0.7021 - dice_coef: 0.5379saved  /tmp/res_segnet_2001.11
# 37/37 [==============================] - 106s 3s/step - loss: 0.9838 - accuracy: 0.7021 - dice_coef: 0.5379 - val_loss: 0.6541 - val_accuracy: 0.7570 - val_dice_coef: 0.6476
# Epoch 13/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9674 - accuracy: 0.7057 - dice_coef: 0.5462saved  /tmp/res_segnet_2001.12
# 37/37 [==============================] - 126s 3s/step - loss: 0.9674 - accuracy: 0.7057 - dice_coef: 0.5462 - val_loss: 0.6441 - val_accuracy: 0.7609 - val_dice_coef: 0.6557
# Epoch 14/30
# 37/37 [==============================] - ETA: 0s - loss: 0.9164 - accuracy: 0.7197 - dice_coef: 0.5637saved  /tmp/res_segnet_2001.13
# 37/37 [==============================] - 113s 3s/step - loss: 0.9164 - accuracy: 0.7197 - dice_coef: 0.5637 - val_loss: 0.6137 - val_accuracy: 0.7646 - val_dice_coef: 0.6660
# Epoch 15/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8936 - accuracy: 0.7269 - dice_coef: 0.5730saved  /tmp/res_segnet_2001.14
# 37/37 [==============================] - 120s 3s/step - loss: 0.8936 - accuracy: 0.7269 - dice_coef: 0.5730 - val_loss: 0.6019 - val_accuracy: 0.7726 - val_dice_coef: 0.6748
# Epoch 16/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8854 - accuracy: 0.7309 - dice_coef: 0.5812saved  /tmp/res_segnet_2001.15
# 37/37 [==============================] - 120s 3s/step - loss: 0.8854 - accuracy: 0.7309 - dice_coef: 0.5812 - val_loss: 0.5925 - val_accuracy: 0.7749 - val_dice_coef: 0.6787
# Epoch 17/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8584 - accuracy: 0.7351 - dice_coef: 0.5879saved  /tmp/res_segnet_2001.16
# 37/37 [==============================] - 119s 3s/step - loss: 0.8584 - accuracy: 0.7351 - dice_coef: 0.5879 - val_loss: 0.5803 - val_accuracy: 0.7781 - val_dice_coef: 0.6832
# Epoch 18/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8519 - accuracy: 0.7380 - dice_coef: 0.5937saved  /tmp/res_segnet_2001.17
# 37/37 [==============================] - 121s 3s/step - loss: 0.8519 - accuracy: 0.7380 - dice_coef: 0.5937 - val_loss: 0.5684 - val_accuracy: 0.7770 - val_dice_coef: 0.6871
# Epoch 19/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8547 - accuracy: 0.7345 - dice_coef: 0.5931saved  /tmp/res_segnet_2001.18
# 37/37 [==============================] - 127s 3s/step - loss: 0.8547 - accuracy: 0.7345 - dice_coef: 0.5931 - val_loss: 0.5623 - val_accuracy: 0.7800 - val_dice_coef: 0.6909
# Epoch 20/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8163 - accuracy: 0.7457 - dice_coef: 0.6086saved  /tmp/res_segnet_2001.19
# 37/37 [==============================] - 113s 3s/step - loss: 0.8163 - accuracy: 0.7457 - dice_coef: 0.6086 - val_loss: 0.5515 - val_accuracy: 0.7853 - val_dice_coef: 0.6967
# Epoch 21/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8335 - accuracy: 0.7397 - dice_coef: 0.6030saved  /tmp/res_segnet_2001.20
# 37/37 [==============================] - 124s 3s/step - loss: 0.8335 - accuracy: 0.7397 - dice_coef: 0.6030 - val_loss: 0.5466 - val_accuracy: 0.7873 - val_dice_coef: 0.7005
# Epoch 22/30
# 37/37 [==============================] - ETA: 0s - loss: 0.8014 - accuracy: 0.7505 - dice_coef: 0.6144saved  /tmp/res_segnet_2001.21
# 37/37 [==============================] - 115s 3s/step - loss: 0.8014 - accuracy: 0.7505 - dice_coef: 0.6144 - val_loss: 0.5301 - val_accuracy: 0.7883 - val_dice_coef: 0.7058
# Epoch 23/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7812 - accuracy: 0.7531 - dice_coef: 0.6188saved  /tmp/res_segnet_2001.22
# 37/37 [==============================] - 118s 3s/step - loss: 0.7812 - accuracy: 0.7531 - dice_coef: 0.6188 - val_loss: 0.5247 - val_accuracy: 0.7871 - val_dice_coef: 0.7068
# Epoch 24/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7727 - accuracy: 0.7566 - dice_coef: 0.6255saved  /tmp/res_segnet_2001.23
# 37/37 [==============================] - 121s 3s/step - loss: 0.7727 - accuracy: 0.7566 - dice_coef: 0.6255 - val_loss: 0.5243 - val_accuracy: 0.7896 - val_dice_coef: 0.7095
# Epoch 25/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7771 - accuracy: 0.7557 - dice_coef: 0.6267saved  /tmp/res_segnet_2001.24
# 37/37 [==============================] - 118s 3s/step - loss: 0.7771 - accuracy: 0.7557 - dice_coef: 0.6267 - val_loss: 0.5078 - val_accuracy: 0.7941 - val_dice_coef: 0.7153
# Epoch 26/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7334 - accuracy: 0.7678 - dice_coef: 0.6414saved  /tmp/res_segnet_2001.25
# 37/37 [==============================] - 113s 3s/step - loss: 0.7334 - accuracy: 0.7678 - dice_coef: 0.6414 - val_loss: 0.5122 - val_accuracy: 0.7961 - val_dice_coef: 0.7154
# Epoch 27/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7651 - accuracy: 0.7574 - dice_coef: 0.6300saved  /tmp/res_segnet_2001.26
# 37/37 [==============================] - 112s 3s/step - loss: 0.7651 - accuracy: 0.7574 - dice_coef: 0.6300 - val_loss: 0.5012 - val_accuracy: 0.7957 - val_dice_coef: 0.7180
# Epoch 28/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7529 - accuracy: 0.7597 - dice_coef: 0.6350saved  /tmp/res_segnet_2001.27
# 37/37 [==============================] - 119s 3s/step - loss: 0.7529 - accuracy: 0.7597 - dice_coef: 0.6350 - val_loss: 0.5000 - val_accuracy: 0.7943 - val_dice_coef: 0.7179
# Epoch 29/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7514 - accuracy: 0.7596 - dice_coef: 0.6360saved  /tmp/res_segnet_2001.28
# 37/37 [==============================] - 126s 3s/step - loss: 0.7514 - accuracy: 0.7596 - dice_coef: 0.6360 - val_loss: 0.4988 - val_accuracy: 0.7958 - val_dice_coef: 0.7199
# Epoch 30/30
# 37/37 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.7759 - dice_coef: 0.6527saved  /tmp/res_segnet_2001.29
# 37/37 [==============================] - 124s 3s/step - loss: 0.7017 - accuracy: 0.7759 - dice_coef: 0.6527 - val_loss: 0.4912 - val_accuracy: 0.7972 - val_dice_coef: 0.7227

# %% [markdown]
# ###10. Results with SegNet (ResNet-50 backbone)

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(model_res.history.history["loss"], label="loss")
plt.plot(model_res.history.history["val_loss"], label="val_loss")
plt.plot( np.argmin(model_res.history.history["val_loss"]), np.min(model_res.history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();
plt.show()
#plt.savefig('/tmp/'+str(config['Model'])+'/train_loss.png')

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(model_res.history.history["dice_coef"], label="dice_coef")
plt.plot(model_res.history.history["val_dice_coef"], label="val_dice_coef")
plt.plot( np.argmax(model_res.history.history["val_dice_coef"]), np.max(model_res.history.history["val_dice_coef"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Dice Coeff")
plt.legend();
plt.show()
#plt.savefig('./Results/plots/'+str(config['Model'])+'/train_dice.png')

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(model_res.history.history["accuracy"], label="accuracy")
plt.plot(model_res.history.history["val_accuracy"], label="val_accuracy")
plt.plot( np.argmax(model_res.history.history["val_accuracy"]), np.max(model_res.history.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend();
plt.show()
# plt.savefig('./Results/plots/'+str(config['Model'])+'/train_accuracy.png

# %%
his_res = model_res.history

# %%
print(model_res.evaluate_segmentation( 
    inp_images_dir="/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_test"  , 
    annotations_dir="/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_test",
    ) 
)

# %%
pred_img_res = model_res.predict_segmentation(
    inp="/content/gdrive/MyDrive/Datasets/dataset1_splitted/images_prepped_test/0016E5_07965.png",
    out_fname="/tmp/pred_img_res.png", overlay_img=True, show_legends=True,
    class_names = [ "Sky", "Building", "Pole","Road","Pavement","Tree","SignSymbol", "Fence", "Car","Pedestrian", "Bicyclist"]
)

from IPython.display import Image
Image('/tmp/pred_img_res.png')

# %% [markdown]
# ###11. Predicting all the test examples using checkpoints of VGG-16 and ResNet-50

# %%
from keras_segmentation.predict import predict_multiple


predict_multiple( 
	checkpoints_path="/tmp/vgg_segnet_111", 
	inp_dir="/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_test", 
	out_dir="outputs_vgg/" 
)

# %%
from keras_segmentation.predict import predict_multiple


predict_multiple( 
	checkpoints_path="/tmp/res_segnet_2001", 
	inp_dir="/content/gdrive/MyDrive/Datasets/dataset1_splitted/annotations_prepped_test", 
	out_dir="outputs_res/" 
)
